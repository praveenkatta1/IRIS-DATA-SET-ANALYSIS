# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
  
import warnings
warnings.filterwarnings('ignore')

# %%
iris_ds=pd.read_csv(r'C:\Users\srisa\Desktop\iris.csv')
iris_ds
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_ds.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris_ds.drop('Id',axis=1,inplace=True)

# %%
iris_ds.head(15)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0             5.1           3.5            1.4           0.2  Iris-setosa
# 1             4.9           3.0            1.4           0.2  Iris-setosa
# 2             4.7           3.2            1.3           0.2  Iris-setosa
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 4             5.0           3.6            1.4           0.2  Iris-setosa
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 11            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
iris_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_ds['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # BAR PLOT

# %%
sns.countplot(x='Species', data=iris_ds,hue='Species')
plt.show()

# %%
iris_ds.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
f=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',data=iris_ds)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.jointplot(x="SepalLengthCm",y="SepalWidthCm",data=iris_ds,kind='reg')
plt.show()

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind='hex',data=iris_ds)

plt.show()

# %%
# %matplotlib inline

# %%
f=sns.FacetGrid(iris_ds,hue='Species',height=4)
f.map(plt.scatter,'SepalLengthCm','SepalWidthCm')

f.add_legend()



plt.show()

# %% [markdown]
# **6. Boxplot or Whisker plot**
# Box plot was was first introduced in year 1969 by Mathematician John Tukey.Box plot give a statical summary of the features being plotted.Top line represent the max value,top edge of box is third Quartile, middle edge represents the median,bottom edge represents the first quartile value.The bottom most line respresent the minimum value of the feature.The height of the box is called as Interquartile range.The black dots on the plot represent the outlier values in the data.

# %%
iris_ds.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
figure=plt.gcf()
figure.set_size_inches(12,6)
figure=sns.boxplot(data=iris_ds,x='Species',y='PetalLengthCm',order=['Iris-virginica','Iris-versicolor','Iris-setosa'],\
                   linewidth=3.0,orient='v',dodge=False,hue='Species')

plt.show()

# %%
iris_ds.boxplot(by="Species", figsize=(12, 6))

plt.show()

# %% [markdown]
# # Strip Plot

# %%
figure=plt.gcf()
figure.set_size_inches(12,6)
figure=sns.stripplot(data=iris_ds,x='Species',y='PetalLengthCm',jitter=True,edgecolor='gray',size=5,palette='winter',hue='Species')

plt.show()

# %%
figure=plt.gcf()
figure.set_size_inches(12,6)
figure=sns.boxplot(data=iris_ds,x='Species',y='SepalLengthCm',hue='Species')
figure=sns.stripplot(data=iris_ds,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',hue='SepalLengthCm')

plt.show()

# %%
figure=plt.gcf()
figure.set_size_inches(10,7)
figure=sns.violinplot(data=iris_ds,x='Species',y='SepalLengthCm',hue='Species')


plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris_ds,hue='Species')
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris_ds,hue='Species')
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris_ds,hue='Species')
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris_ds,hue='Species')




plt.show()

# %% [markdown]
# #  PAIR PLOT

# %%
sns.pairplot(data=iris_ds,kind='scatter')


plt.show()

# %%
sns.pairplot(iris_ds,hue='Species')

plt.show()

# %% [markdown]
# **11. Heat map**
# Heat map is used to find out the correlation between different features in the dataset.High positive or negative value shows that the features have high correlation.This helps us to select the parmeters for machine learning.

# %%
hm=plt.gcf()
hm.set_size_inches(12,6)
correlation_matrix = iris_ds.select_dtypes(include=['float64', 'int64']).corr()


hm = sns.heatmap(correlation_matrix, annot=True, cmap='cubehelix', linewidths=1, linecolor='k', 
                 square=True, mask=False, vmin=-1, vmax=1, 
                 cbar_kws={"orientation": "vertical"}, cbar=True)


plt.show()

# %% [markdown]
# **12. Distribution plot:**
# The distribution plot is suitable for comparing range and distribution for groups of numerical data. Data is plotted as value points along an axis. You can choose to display only the value points to see the distribution of values, a bounding box to see the range of values, or a combination of both as shown here.The distribution plot is not relevant for detailed analysis of the data as it deals with a summary of the data distribution.

# %%
iris_ds.hist(edgecolor='black', linewidth=1)
fig=plt.gcf()
fig.set_size_inches(12,6)


plt.show()

# %% [markdown]
# **13. Swarm plot**
# It looks a bit like a friendly swarm of bees buzzing about their hive. More importantly, each data point is clearly visible and no data are obscured by overplotting.A beeswarm plot improves upon the random jittering approach to move data points the minimum distance away from one another to avoid overlays. The result is a plot where you can see each distinct data point, like shown in below plot

# %%
sns.set_style('darkgrid')
figure=plt.gcf()
figure.set_size_inches(12,6)

figure= sns.swarmplot(data=iris_ds,x='Species',y='PetalLengthCm',hue='Species')


plt.show()

# %%
sns.set_style('white')
figure=plt.gcf()
figure.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=iris_ds, inner=None,hue='Species')
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=iris_ds,color="white", edgecolor="black",hue='Species')


plt.show()

# %% [markdown]
# # LM PLOT

# %%
figure=sns.lmplot(x="PetalLengthCm", y="PetalWidthCm",data=iris_ds)

plt.show()

# %%
sns.set_style('whitegrid')
F=sns.FacetGrid(iris_ds, hue="Species", height=6) 
F.map(sns.kdeplot, "PetalLengthCm") 
F.add_legend()
plt.ioff() 



plt.show()

# %% [markdown]
# # Factor Plot

# %%
sns.catplot(x='Species', y='SepalLengthCm', data=iris_ds, kind='point')
plt.ioff()
plt.show()

# %%
sns.catplot(x='Species', data=iris_ds, kind='count')
plt.ioff()
plt.show()

# %%
sns.catplot(x='Species', y='SepalLengthCm', data=iris_ds, kind='bar')
plt.ioff()
plt.show()

# %% [markdown]
# # BOXEN PLOT

# %%
figure=plt.gcf()
figure.set_size_inches(10,7)
figure=sns.boxenplot(x='Species',y='SepalLengthCm',data=iris_ds,hue='Species')


plt.show()

# %%
figure=plt.gcf()
figure.set_size_inches(10,7)
figure=sns.boxenplot(x='Species',y='PetalLengthCm',data=iris_ds,hue='Species')


plt.show()

# %% [markdown]
# # KDE PLOT

# %%
sub=iris_ds[iris_ds['Species']=='Iris-setosa']
sns.kdeplot(data=sub[['SepalLengthCm', 'SepalWidthCm']], shade=True, shade_lowest=False, color="purple")

plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')


plt.show()

# %% [markdown]
# # DASH BOARD

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.boxplot(x="Species", y="PetalLengthCm", data=iris_ds,ax=axes[0,0])
k2=sns.violinplot(x='Species',y='PetalLengthCm',data=iris_ds,ax=axes[0,1])
k3=sns.stripplot(x='Species',y='SepalLengthCm',data=iris_ds,jitter=True,edgecolor='gray',size=8,palette='winter',orient='v',ax=axes[1,0])

axes[1,1].hist(iris_ds.PetalLengthCm,bins=100)

plt.show()

# %% [markdown]
# # STACKED HISTOGRAM

# %%
iris_ds['Species'] = iris_ds['Species'].astype('category')

# %%
iris_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
list1 = list()
mylabels = list()

for gen in iris_ds['Species'].cat.categories:
    list1.append(iris_ds[iris_ds['Species'] == gen]['SepalLengthCm'])
    mylabels.append(gen)


plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)


plt.legend(title='Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Stacked Histogram of Sepal Length by Species')
plt.show()

# %%
list1 = list()
mylabels = list()

for gen in iris_ds['Species'].cat.categories:
    list1.append(iris_ds[iris_ds['Species'] == gen]['PetalLengthCm'])
    mylabels.append(gen)


plt.hist(list1, bins=30, stacked=True, rwidth=1, label=mylabels)


plt.legend(title='Species')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.title('Stacked Histogram of Petal Length by Species')
plt.show()

# %% [markdown]
# # AREA PLOT

# %%
iris_ds.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6));

plt.show()

# %% [markdown]
# # DIST PLOT

# %%
sns.distplot(iris_ds['SepalLengthCm'],kde=True,bins=20);

plt.show()

# %%
sns.distplot(iris_ds['PetalLengthCm'],kde=True,bins=20);

plt.show()
